# %%
#code to print all the keywords present in the python
import keyword
print(keyword.kwlist)
a=len(keyword.kwlist)
print(a)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# 35

# %%
l1=[1,2,3,4,5,6]
for x in l1:
  print(x)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
len(l1)
# Out:
# 6

# %%
l1.append(7)

# %%
print(l1)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
l2=[8,9]

l3=l1+l2
l3
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
l1=[1,1,1,2,2,2,3,3,3,4,4]

# %%
l2=[]
for x in l1:
  if x not in l2:
    l2.append(x)
l2
# Out:
# [1, 2, 3, 4]

# %%
l2=list(set(l1))
l2
# Out:
# [1, 2, 3, 4]

# %%
a=10
b=1.5
c='abc'

print(type(a),type(b),type(c))
# Out:
# <class 'int'> <class 'float'> <class 'str'>

# %%
for x in range(6):
  print(x)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
#slicing
l1=[1,2,3,4,5,6,7,8]
print(l1[:4])
# Out:
# [1, 2, 3, 4]

# %%
l1[-1] #printing the last element
# Out:
# 8

# %%
l1[::-1] #reversing the list
# Out:
# [8, 7, 6, 5, 4, 3, 2, 1]

# %%
str1=input("Enter a string:")
str2=str1[::-1]

if str1==str2:
  print("The string is a Palindrome:")
else:
  print("The string is not a Plaindrome")
# Out:
# Enter a string:jalaj
# The string is a Palindrome:

# %%
import random
numbers=[1,2,3,4,5,6,7,8]
random.shuffle(numbers)
print(numbers)
# Out:
# [5, 6, 4, 8, 3, 2, 7, 1]

# %%
num=[1,2,3,4,5,6,7,8,9]
sum(num)
# Out:
# 45

# %%
#Membership operator
days=["Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"]
"Wednesday" in days
# Out:
# False

# %%
"Friday" not in days
# Out:
# False

# %%
nums=[1,2,3,4,5,6,7,8,9,1,2]
print(nums)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9, 1, 2]

# %%
nums.count(2)
# Out:
# 2

# %%
list_1=[1,2,3,4]
print(list_1)
list_2=list_1.copy()
print(list_2)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4]

# %%
list=["red","Orange","black","Blue"]
print(list)
list.clear()
list
# Out:
# ['red', 'Orange', 'black', 'Blue']
# []

# %%
a=["a","b","c","d"]
print(a)
a.append("e")
print(a)
# Out:
# ['a', 'b', 'c', 'd']
# ['a', 'b', 'c', 'd', 'e']

# %%
nums=[1,2,3,1,5,6,7,8,5,2,1]
print(nums)
nums.count(1)
# Out:
# [1, 2, 3, 1, 5, 6, 7, 8, 5, 2, 1]
# 3

# %%
list_1=[1,2,3,4]
print(list_1)
list_2=list_1.copy()
print(list_2)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4]

# %%
list_1=[1,2,3,4]
b=[5,6,7,8]
list_1.extend(b)
print(list_1)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
#Tuples
a=(4)
print(type(a))
b=(5,)
print(type(b))
# Out:
# <class 'int'>
# <class 'tuple'>

# %%
a=(1,2,3,4,4.5,5.5,2.6)
print(a)
# Out:
# (1, 2, 3, 4, 4.5, 5.5, 2.6)

# %%
c=("one","two","three")
c
# Out:
# ('one', 'two', 'three')

# %%
mix=("HII",70256,66.5)
print(mix)
print(mix[0])
# Out:
# ('HII', 70256, 66.5)
# HII

# %%
#Dictionary
a={"name":"Deeksha",
   "Class":"5CIT02",
   "Program":"CSE"}
print(a)
# Out:
# {'name': 'Deeksha', 'Class': '5CIT02', 'Program': 'CSE'}

# %%
len(a)
# Out:
# 3

# %%
type(a)
# Out:
# dict

# %%
x=a.keys()
print(x)
y=a.values()
print(y)
# Out:
# dict_keys(['name', 'Class', 'Program'])
# dict_values(['Deeksha', '5CIT02', 'CSE'])

# %%
z=a.items()
z
# Out:
# dict_items([('name', 'Deeksha'), ('Class', '5CIT02'), ('Program', 'CSE')])

# %%
 #Sets

# %%
s1={1,2,3,4}
print(s1)
# Out:
# {1, 2, 3, 4}

# %%
number={1,2,3,1,5,6,7,8,5,2,1}
print(number)

print(len(number))
print(type(number))
# Out:
# {1, 2, 3, 5, 6, 7, 8}
# 7
# <class 'set'>

# %%
#Functions
def add():
  a=2
  b=3
  sum=a+b
  return sum
add()
print(add())
# Out:
# 5
